# %%
from HourglassClasses import tests

tests.all_tests()
# Out:
# Testing DihedralElement class.
# DihedralElement tests complete.
#
# Testing HalfStrand class.
# HalfStrand tests complete.
#
# Testing HalfHourglass class.
# HalfHourglass tests complete.
#
# Testing Vertex class.
# Vertex tests complete.
#
# Testing Face class.
# Face tests complete.
#
# Testing HourglassPlabicGraph class.
# HourglassPlabicGraph test complete.
#
# Testing moves.
# Move tests complete.
#
# Testing serialization.
# Serialization tests complete.
#
# Testing is_fully_reduced.
# is_fully_reduced tests complete.
#
# Testing separation_labeling.
# separation_labeling tests complete.
